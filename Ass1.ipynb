# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mongi**

# %% [markdown]
# Aim to be Data Analyst

# %% [markdown]
# *I am interested in data analytics because a lot can be acquired from the right presenting, analyzing and understanding of data which can lead to many innovative interventions in a lot of areas of human existence. I would like to play my part in this discovery.*

# %% [markdown]
# ### Will give the sum of two numbers

# %%
1+2
# Out:
# 3

# %% [markdown]
# ______________

# %% [markdown]
# 1. one

# %% [markdown]
# 2. two

# %% [markdown]
# 3. three

# %% [markdown]
#  (https://www.google.com)
